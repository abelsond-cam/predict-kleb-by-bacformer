# %%
import pandas as pd
import pyarrow.parquet as pq

file = "/home/dca36/rds/rds-floto-bacterial-4k08a2yyQLw/david/processed/klebsiella_protein_sequences/SAMD00052611_protein_sequences.parquet"

df = pd.read_parquet(file, engine="pyarrow")
df.head()
# Out:
#       sample_id                                        genome_info  \
# 0  SAMD00052611  {'accession_id': ['SAMD00052611.contig00001', ...
#
#          processing_timestamp
# 0  2026-02-04T21:53:16.526902
