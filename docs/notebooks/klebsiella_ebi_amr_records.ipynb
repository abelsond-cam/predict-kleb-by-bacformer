# %%
# Klebsiella EBI AMR records

# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file = '/home/dca36/rds/rds-floto-bacterial-4k08a2yyQLw/david/raw/klebsiella_ebi_amr_records_20260216.csv'
df = pd.read_csv(file) # Comma separated values

# Print the first 5 rows of the dataframe
display(df.head())
# Out:
# /tmp/ipykernel_3605762/1929461837.py:10: DtypeWarning: Columns (16,20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file) # Comma separated values
#   phenotype-antibiotic_name phenotype-resistance_phenotype  \
# 0               ceftriaxone                      resistant
# 1                cefuroxime                      resistant
# 2              levofloxacin                      resistant
# 3                gentamicin                      resistant
# 4                  imipenem                      resistant
#
#   phenotype-gen_measurement phenotype-ast_standard  \
# 0                 > 32 mg/L                   CLSI
# 1                 > 16 mg/L                   CLSI
# 2                  > 4 mg/L                   CLSI
# 3                  > 8 mg/L                   CLSI
# 4                  > 8 mg/L                   CLSI
#
#   phenotype-laboratory_typing_method phenotype-platform  \
# 0                     broth dilution         BD Phoenix
# 1                     broth dilution         BD Phoenix
# 2                     broth dilution         BD Phoenix
# 3                     broth dilution         BD Phoenix
# 4                     broth dilution         BD Phoenix
#
#   phenotype-BioSample_ID phenotype-assembly_ID phenotype-genus  \
# 0           SAMN06437146       GCA_022066305.1      Klebsiella
# 1           SAMN06437146       GCA_022066305.1      Klebsiella
# 2           SAMN06437146       GCA_022066305.1      Klebsiella
# 3           SAMN06437146       GCA_022066305.1      Klebsiella
# 4           SAMN06437146       GCA_022066305.1      Klebsiella
#
#        phenotype-species  ... phenotype-isolation_latitude  \
# 0  Klebsiella pneumoniae  ...                    29.710689
# 1  Klebsiella pneumoniae  ...                    29.710689
# 2  Klebsiella pneumoniae  ...                    29.710689
# 3  Klebsiella pneumoniae  ...                    29.710689
# 4  Klebsiella pneumoniae  ...                    29.710689
#
#   phenotype-isolation_longitude phenotype-AMR_associated_publications  \
# 0                    -95.400586            29323230;33075053;33659219
# 1                    -95.400586            29323230;33075053;33659219
# 2                    -95.400586            29323230;33075053;33659219
# 3                    -95.400586            29323230;33075053;33659219
# 4                    -95.400586            29323230;33075053;33659219
#
#   phenotype-Updated_phenotype_CLSI  phenotype-Updated_phenotype_EUCAST  \
# 0                        resistant                           resistant
# 1                        resistant                           resistant
# 2                        resistant                           resistant
# 3                        resistant                           resistant
# 4                        resistant                           resistant
#
#    phenotype-used_ECOFF          phenotype-database         phenotype-country  \
# 0                    no  PATRIC;CABBAGE_PubMed_data  United States of America
# 1                    no  PATRIC;CABBAGE_PubMed_data  United States of America
# 2                    no  PATRIC;CABBAGE_PubMed_data  United States of America
# 3                    no  PATRIC;CABBAGE_PubMed_data  United States of America
# 4                    no  PATRIC;CABBAGE_PubMed_data  United States of America
#
#   phenotype-geographical_region phenotype-geographical_subregion
# 0                      Americas                 Northern America
# 1                      Americas                 Northern America
# 2                      Americas                 Northern America
# 3                      Americas                 Northern America
# 4                      Americas                 Northern America
#
# [5 rows x 30 columns]

# %%
# Create a binary column for "Susceptible" and "Resistant"

# %%
# Lets get a column Sample_ID = "phentoype-BioSample_ID"
df['Sample_ID'] = df['phenotype-BioSample_ID']

# How many unique Klebsiella Genomes Sample_IDs are there?
print(f"Number of unique Klebsiella Genomes: {df['Sample_ID'].nunique()}")

# How many unique antibiotics are tested (use nunique on column "phenotype-antibiotic_name")
unique_antibiotics = df['phenotype-antibiotic_name'].nunique()
# Order descending and display all with > 1000 records
df_antibiotics = df.groupby('phenotype-antibiotic_name')['phenotype-antibiotic_name'].count().sort_values(ascending=False)
display(df_antibiotics[df_antibiotics > 1000])
# Out:
# 10260
# phenotype-antibiotic_name
# meropenem                        8086
# gentamicin                       6837
# ceftazidime                      6757
# ciprofloxacin                    6729
# amikacin                         5682
# trimethoprim-sulfamethoxazole    5639
# piperacillin-tazobactam          5348
# cefepime                         4750
# ceftriaxone                      4602
# imipenem                         4580
# tobramycin                       4351
# ampicillin                       4223
# aztreonam                        4171
# cefoxitin                        3995
# cefotaxime                       3844
# levofloxacin                     3707
# cefuroxime                       3552
# ampicillin-sulbactam             3332
# cefazolin                        3271
# tigecycline                      3059
# colistin                         2990
# tetracycline                     2891
# ertapenem                        2777
# amoxicillin-clavulanic acid      2332
# pentizidone                      2317
# azithromycin                     1995
# nitrofurantoin                   1905
# minocycline                      1512
# fosfomycin                       1405
# chloramphenicol                  1391
# doripenem                        1288
# cefpodoxime                      1239
# cefotaxime-clavulanic acid       1074
# Name: phenotype-antibiotic_name, dtype: int64
